# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms, models
from PIL import Image
from matplotlib import pyplot as plt
import os
import numpy as np
from math import log10
from torch.autograd import Variable
from random import choice
from torch.utils.data import random_split
from sklearn.metrics import mean_squared_error
import arrow
import time as t

# %%
torch.cuda.empty_cache()
torch.cuda.current_device()
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# 1
# GeForce RTX 2080 Ti

# %%
class LARSONet(nn.Module):
    def __init__(self):
        super(LARSONet, self).__init__()
        # in layer
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, padding=1, bias=False)
        self.relu1 = nn.ReLU(inplace=True)
        # hidden layers
        hidden_layers = []
        for i in range(15):
            hidden_layers.append(nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1, bias=False))
            hidden_layers.append(nn.BatchNorm2d(64))
            hidden_layers.append(nn.ReLU(inplace=True))
        self.mid_layer = nn.Sequential(*hidden_layers)
        # out layer
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=1, kernel_size=3, padding=1, bias=False)

    def forward(self, x):
        out1 = self.relu1(self.conv1(x))
        out = self.mid_layer(out1)
        out = self.conv3(out+out1)
        return out
    
class dp_patches(Dataset):
    def __init__(self,x,y,percent_noise):
        self.x = torch.load(x)
        self.y = torch.load(y)
        self.percent_noise = percent_noise
        self.noise = torch.randn(self.x.shape)
        self.xnoise = self.noise * self.percent_noise + self.x#*(1-self.percent_noise)
        rand_pts = torch.from_numpy(np.random.randint(0,self.x.shape[0],1000))
        self.x = self.x[rand_pts]
        self.y = self.y[rand_pts]
        self.xnoise = self.xnoise[rand_pts]
        self.z = torch.clone(self.xnoise)
    def __getitem__(self,idx):
        x = self.x[idx].to('cuda')
        z = self.xnoise[idx].to('cuda')
#         x -= torch.min(x)
#         x /= torch.max(x)
        y = self.y[idx].to('cuda')
#         y -= torch.min(y)
#         y /= torch.max(y)

        return z, y, x
    def __len__(self):
        return self.x.shape[0]

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data,0.0,0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data,1.0,0.02)
        nn.init.constant_(m.bias.data,0)

# %%
dset = dp_patches('ams_50x100.pt','mod_50x100.pt', .5)

train_dset_size = int(0.80*len(dset))
valid_dset_size = int(0.5*(len(dset) - train_dset_size))
test_dset_size = int(0.5*(len(dset) - train_dset_size))

train_dset, valid_dset, test_dset = random_split(dset,[train_dset_size,valid_dset_size,test_dset_size])

train_dataloader = DataLoader(dataset=train_dset, batch_size=2, shuffle=True, num_workers=0)
valid_dataloader = DataLoader(dataset=valid_dset, batch_size=1, shuffle=True, num_workers=0)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = LARSONet().to(device)
model.apply(weights_init)
criterion = nn.MSELoss()
lr = 1e-4
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
plt.figure()
plt.imshow(dset.x[999,0,:,:],cmap='jet')
plt.colorbar()

plt.figure()
plt.imshow(dset.y[999,0,:,:],cmap='jet')
plt.colorbar()

plt.figure()
plt.imshow(dset.z[999,0,:,:],cmap='jet')
plt.colorbar()

# %%
t0 = t.time()

def train(epoch):
    epoch_loss = 0
    c=0
    for z,y,x in train_dataloader:
        c+=1

        target = y-z
        predicted = model(z)

        loss = criterion(predicted, target)
        epoch_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        

#         print("===> Epoch[{}]({}/{}): Loss: {:.4f}".format(epoch, c, len(train_dataloader), loss.item()))
    print("===> Epoch {} Complete: Avg. Loss: {:.4f}".format(epoch, epoch_loss / len(train_dataloader)))
    
def validate():
    validate.avg_psnr = 0
    avg_psnr = 0
    model.eval()
    with torch.no_grad():
        for zz,yy,xx in valid_dataloader:
            target = yy-zz
            predicted = model(zz)
            mse = criterion(predicted, target)
            modis = yy.cpu().numpy().squeeze().squeeze();
            amsre = zz.cpu().numpy().squeeze();
            adj = predicted.cpu().numpy().squeeze();
            psnr = 10 * np.log10(np.power(np.max(modis),2) / mean_squared_error(modis,amsre+adj))
            validate.avg_psnr += (psnr / len(valid_dataloader))
        
    print("===> Avg. PSNR: {:.4f} dB".format(validate.avg_psnr))
    
def save_checkpoint(state):
    model_out_path = "model_epoch_{}.pth".format(epoch)
    torch.save(state, model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))
    
glob_psnr = 0
num_epochs = 200
coun = 1
for epoch in range(1, num_epochs + 1):
    train(epoch)
    if epoch % 2 == 0:
        validate()
        glob_psnr += validate.avg_psnr
        print("===> Running Avg. PSNR: {:.4f} dB".format(glob_psnr/(coun)))
        coun +=1

t1 = t.time()
print('it took {} seconds'.format(t1-t0))
# Out:
# ===> Epoch 1 Complete: Avg. Loss: 0.3074
# ===> Epoch 2 Complete: Avg. Loss: 0.1894
# ===> Avg. PSNR: 22.5345 dB
# ===> Running Avg. PSNR: 22.5345 dB
# ===> Epoch 3 Complete: Avg. Loss: 0.9320
# ===> Epoch 4 Complete: Avg. Loss: 0.5434
# ===> Avg. PSNR: 24.4178 dB
# ===> Running Avg. PSNR: 23.4761 dB
# ===> Epoch 5 Complete: Avg. Loss: 0.3364
# ===> Epoch 6 Complete: Avg. Loss: 0.2936
# ===> Avg. PSNR: 27.5226 dB
# ===> Running Avg. PSNR: 24.8250 dB
# ===> Epoch 7 Complete: Avg. Loss: 0.2340
# ===> Epoch 8 Complete: Avg. Loss: 0.2014
# ===> Avg. PSNR: 28.7331 dB
# ===> Running Avg. PSNR: 25.8020 dB
# ===> Epoch 9 Complete: Avg. Loss: 0.2112
# ===> Epoch 10 Complete: Avg. Loss: 0.1869
# ===> Avg. PSNR: 29.2661 dB
# ===> Running Avg. PSNR: 26.4948 dB
# ===> Epoch 11 Complete: Avg. Loss: 0.1650
# ===> Epoch 12 Complete: Avg. Loss: 0.1559
# ===> Avg. PSNR: 28.9439 dB
# ===> Running Avg. PSNR: 26.9030 dB
# ===> Epoch 13 Complete: Avg. Loss: 0.2361
# ===> Epoch 14 Complete: Avg. Loss: 0.2513
# ===> Avg. PSNR: 27.0411 dB
# ===> Running Avg. PSNR: 26.9227 dB
# ===> Epoch 15 Complete: Avg. Loss: 0.2061
# ===> Epoch 16 Complete: Avg. Loss: 0.1625
# ===> Avg. PSNR: 28.9978 dB
# ===> Running Avg. PSNR: 27.1821 dB
# ===> Epoch 17 Complete: Avg. Loss: 0.2006
# ===> Epoch 18 Complete: Avg. Loss: 0.1633
# ===> Avg. PSNR: 27.7362 dB
# ===> Running Avg. PSNR: 27.2437 dB
# ===> Epoch 19 Complete: Avg. Loss: 0.1780
# ===> Epoch 20 Complete: Avg. Loss: 0.1483
# ===> Avg. PSNR: 29.6432 dB
# ===> Running Avg. PSNR: 27.4836 dB
# ===> Epoch 21 Complete: Avg. Loss: 0.1379
# ===> Epoch 22 Complete: Avg. Loss: 0.1328
# ===> Avg. PSNR: 29.7703 dB
# ===> Running Avg. PSNR: 27.6915 dB
# ===> Epoch 23 Complete: Avg. Loss: 0.1549
# ===> Epoch 24 Complete: Avg. Loss: 0.1306
# ===> Avg. PSNR: 30.4820 dB
# ===> Running Avg. PSNR: 27.9240 dB
# ===> Epoch 25 Complete: Avg. Loss: 0.1350
# ===> Epoch 26 Complete: Avg. Loss: 0.1298
# ===> Avg. PSNR: 29.8959 dB
# ===> Running Avg. PSNR: 28.0757 dB
# ===> Epoch 27 Complete: Avg. Loss: 0.1174
# ===> Epoch 28 Complete: Avg. Loss: 0.1197
# ===> Avg. PSNR: 30.9210 dB
# ===> Running Avg. PSNR: 28.2790 dB
# ===> Epoch 29 Complete: Avg. Loss: 0.1154
# ===> Epoch 30 Complete: Avg. Loss: 0.1570
# ===> Avg. PSNR: 28.8344 dB
# ===> Running Avg. PSNR: 28.3160 dB
# ===> Epoch 31 Complete: Avg. Loss: 0.1402
# ===> Epoch 32 Complete: Avg. Loss: 0.1150
# ===> Avg. PSNR: 30.6973 dB
# ===> Running Avg. PSNR: 28.4648 dB
# ===> Epoch 33 Complete: Avg. Loss: 0.1164
# ===> Epoch 34 Complete: Avg. Loss: 0.1156
# ===> Avg. PSNR: 29.4503 dB
# ===> Running Avg. PSNR: 28.5228 dB
# ===> Epoch 35 Complete: Avg. Loss: 0.1439
# ===> Epoch 36 Complete: Avg. Loss: 0.1105
# ===> Avg. PSNR: 30.8006 dB
# ===> Running Avg. PSNR: 28.6493 dB
# ===> Epoch 37 Complete: Avg. Loss: 0.1315
# ===> Epoch 38 Complete: Avg. Loss: 0.1153
# ===> Avg. PSNR: 30.4286 dB
# ===> Running Avg. PSNR: 28.7430 dB
# ===> Epoch 39 Complete: Avg. Loss: 0.0989
# ===> Epoch 40 Complete: Avg. Loss: 0.1060
# ===> Avg. PSNR: 31.4698 dB
# ===> Running Avg. PSNR: 28.8793 dB
# ===> Epoch 41 Complete: Avg. Loss: 0.1024
# ===> Epoch 42 Complete: Avg. Loss: 0.1176
# ===> Avg. PSNR: 31.0806 dB
# ===> Running Avg. PSNR: 28.9842 dB
# ===> Epoch 43 Complete: Avg. Loss: 0.1044
# ===> Epoch 44 Complete: Avg. Loss: 0.0984
# ===> Avg. PSNR: 30.9310 dB
# ===> Running Avg. PSNR: 29.0726 dB
# ===> Epoch 45 Complete: Avg. Loss: 0.0947
# ===> Epoch 46 Complete: Avg. Loss: 0.1003
# ===> Avg. PSNR: 29.7284 dB
# ===> Running Avg. PSNR: 29.1012 dB
# ===> Epoch 47 Complete: Avg. Loss: 0.0948
# ===> Epoch 48 Complete: Avg. Loss: 0.0902
# ===> Avg. PSNR: 30.8370 dB
# ===> Running Avg. PSNR: 29.1735 dB
# ===> Epoch 49 Complete: Avg. Loss: 0.0978
# ===> Epoch 50 Complete: Avg. Loss: 0.0944
# ===> Avg. PSNR: 30.4501 dB
# ===> Running Avg. PSNR: 29.2245 dB
# ===> Epoch 51 Complete: Avg. Loss: 0.0906
# ===> Epoch 52 Complete: Avg. Loss: 0.0923
# ===> Avg. PSNR: 30.7770 dB
# ===> Running Avg. PSNR: 29.2843 dB
# ===> Epoch 53 Complete: Avg. Loss: 0.0924
# ===> Epoch 54 Complete: Avg. Loss: 0.1513
# ===> Avg. PSNR: 29.8174 dB
# ===> Running Avg. PSNR: 29.3040 dB
# ===> Epoch 55 Complete: Avg. Loss: 0.1194
# ===> Epoch 56 Complete: Avg. Loss: 0.0930
# ===> Avg. PSNR: 31.7475 dB
# ===> Running Avg. PSNR: 29.3913 dB
# ===> Epoch 57 Complete: Avg. Loss: 0.1022
# ===> Epoch 58 Complete: Avg. Loss: 0.1004
# ===> Avg. PSNR: 31.6498 dB
# ===> Running Avg. PSNR: 29.4692 dB
# ===> Epoch 59 Complete: Avg. Loss: 0.0979
# ===> Epoch 60 Complete: Avg. Loss: 0.0990
# ===> Avg. PSNR: 32.1573 dB
# ===> Running Avg. PSNR: 29.5588 dB
# ===> Epoch 61 Complete: Avg. Loss: 0.0885
# ===> Epoch 62 Complete: Avg. Loss: 0.0842
# ===> Avg. PSNR: 31.1936 dB
# ===> Running Avg. PSNR: 29.6115 dB
# ===> Epoch 63 Complete: Avg. Loss: 0.0914
# ===> Epoch 64 Complete: Avg. Loss: 0.0888
# ===> Avg. PSNR: 32.3579 dB
# ===> Running Avg. PSNR: 29.6973 dB
# ===> Epoch 65 Complete: Avg. Loss: 0.0826
# ===> Epoch 66 Complete: Avg. Loss: 0.1022
# ===> Avg. PSNR: 30.8115 dB
# ===> Running Avg. PSNR: 29.7311 dB
# ===> Epoch 67 Complete: Avg. Loss: 0.0980
# ===> Epoch 68 Complete: Avg. Loss: 0.0887
# ===> Avg. PSNR: 30.1982 dB
# ===> Running Avg. PSNR: 29.7448 dB
# ===> Epoch 69 Complete: Avg. Loss: 0.0899
# ===> Epoch 70 Complete: Avg. Loss: 0.0817
# ===> Avg. PSNR: 32.0069 dB
# ===> Running Avg. PSNR: 29.8094 dB
# ===> Epoch 71 Complete: Avg. Loss: 0.0824
# ===> Epoch 72 Complete: Avg. Loss: 0.0830
# ===> Avg. PSNR: 32.0170 dB
# ===> Running Avg. PSNR: 29.8708 dB
# ===> Epoch 73 Complete: Avg. Loss: 0.0854
# ===> Epoch 74 Complete: Avg. Loss: 0.0815
# ===> Avg. PSNR: 31.4156 dB
# ===> Running Avg. PSNR: 29.9125 dB
# ===> Epoch 75 Complete: Avg. Loss: 0.0908
# ===> Epoch 76 Complete: Avg. Loss: 0.0820
# ===> Avg. PSNR: 31.7138 dB
# ===> Running Avg. PSNR: 29.9599 dB
# ===> Epoch 77 Complete: Avg. Loss: 0.0896
# ===> Epoch 78 Complete: Avg. Loss: 0.0825
# ===> Avg. PSNR: 32.4039 dB
# ===> Running Avg. PSNR: 30.0226 dB
# ===> Epoch 79 Complete: Avg. Loss: 0.0848
# ===> Epoch 80 Complete: Avg. Loss: 0.0880
# ===> Avg. PSNR: 31.6620 dB
# ===> Running Avg. PSNR: 30.0636 dB
# ===> Epoch 81 Complete: Avg. Loss: 0.0832
# ===> Epoch 82 Complete: Avg. Loss: 0.0792
# ===> Avg. PSNR: 32.1249 dB
# ===> Running Avg. PSNR: 30.1138 dB
# ===> Epoch 83 Complete: Avg. Loss: 0.0791
# ===> Epoch 84 Complete: Avg. Loss: 0.0722
# ===> Avg. PSNR: 31.9580 dB
# ===> Running Avg. PSNR: 30.1578 dB
# ===> Epoch 85 Complete: Avg. Loss: 0.0775
# ===> Epoch 86 Complete: Avg. Loss: 0.0840
# ===> Avg. PSNR: 31.6410 dB
# ===> Running Avg. PSNR: 30.1923 dB
# ===> Epoch 87 Complete: Avg. Loss: 0.0885
# ===> Epoch 88 Complete: Avg. Loss: 0.0770
# ===> Avg. PSNR: 32.4220 dB
# ===> Running Avg. PSNR: 30.2429 dB
# ===> Epoch 89 Complete: Avg. Loss: 0.0836
# ===> Epoch 90 Complete: Avg. Loss: 0.0715
# ===> Avg. PSNR: 32.8371 dB
# ===> Running Avg. PSNR: 30.3006 dB
# ===> Epoch 91 Complete: Avg. Loss: 0.0704
# ===> Epoch 92 Complete: Avg. Loss: 0.0761
# ===> Avg. PSNR: 32.4138 dB
# ===> Running Avg. PSNR: 30.3465 dB
# ===> Epoch 93 Complete: Avg. Loss: 0.1085
# ===> Epoch 94 Complete: Avg. Loss: 0.0715
# ===> Avg. PSNR: 32.3398 dB
# ===> Running Avg. PSNR: 30.3889 dB
# ===> Epoch 95 Complete: Avg. Loss: 0.0720
# ===> Epoch 96 Complete: Avg. Loss: 0.0805
# ===> Avg. PSNR: 31.8320 dB
# ===> Running Avg. PSNR: 30.4190 dB
# ===> Epoch 97 Complete: Avg. Loss: 0.0748
# ===> Epoch 98 Complete: Avg. Loss: 0.0738
# ===> Avg. PSNR: 31.9535 dB
# ===> Running Avg. PSNR: 30.4503 dB
# ===> Epoch 99 Complete: Avg. Loss: 0.0777
# ===> Epoch 100 Complete: Avg. Loss: 0.0795
# ===> Avg. PSNR: 29.5437 dB
# ===> Running Avg. PSNR: 30.4322 dB
# ===> Epoch 101 Complete: Avg. Loss: 0.0807
# ===> Epoch 102 Complete: Avg. Loss: 0.0696
# ===> Avg. PSNR: 32.7555 dB
# ===> Running Avg. PSNR: 30.4777 dB
# ===> Epoch 103 Complete: Avg. Loss: 0.0744
# ===> Epoch 104 Complete: Avg. Loss: 0.0664
# ===> Avg. PSNR: 30.7747 dB
# ===> Running Avg. PSNR: 30.4834 dB
# ===> Epoch 105 Complete: Avg. Loss: 0.0692
# ===> Epoch 106 Complete: Avg. Loss: 0.0711
# ===> Avg. PSNR: 30.9147 dB
# ===> Running Avg. PSNR: 30.4916 dB
# ===> Epoch 107 Complete: Avg. Loss: 0.0769
# ===> Epoch 108 Complete: Avg. Loss: 0.0669
# ===> Avg. PSNR: 33.0920 dB
# ===> Running Avg. PSNR: 30.5397 dB
# ===> Epoch 109 Complete: Avg. Loss: 0.0737
# ===> Epoch 110 Complete: Avg. Loss: 0.0745
# ===> Avg. PSNR: 32.4071 dB
# ===> Running Avg. PSNR: 30.5737 dB
# ===> Epoch 111 Complete: Avg. Loss: 0.0842
# ===> Epoch 112 Complete: Avg. Loss: 0.0768
# ===> Avg. PSNR: 32.6715 dB
# ===> Running Avg. PSNR: 30.6111 dB
# ===> Epoch 113 Complete: Avg. Loss: 0.0642
# ===> Epoch 114 Complete: Avg. Loss: 0.0668
# ===> Avg. PSNR: 31.8159 dB
# ===> Running Avg. PSNR: 30.6323 dB
# ===> Epoch 115 Complete: Avg. Loss: 0.0687
# ===> Epoch 116 Complete: Avg. Loss: 0.0656
# ===> Avg. PSNR: 33.2144 dB
# ===> Running Avg. PSNR: 30.6768 dB
# ===> Epoch 117 Complete: Avg. Loss: 0.0698
# ===> Epoch 118 Complete: Avg. Loss: 0.0734
# ===> Avg. PSNR: 32.4526 dB
# ===> Running Avg. PSNR: 30.7069 dB
# ===> Epoch 119 Complete: Avg. Loss: 0.0663
# ===> Epoch 120 Complete: Avg. Loss: 0.0769
# ===> Avg. PSNR: 32.3686 dB
# ===> Running Avg. PSNR: 30.7346 dB
# ===> Epoch 121 Complete: Avg. Loss: 0.0633
# ===> Epoch 122 Complete: Avg. Loss: 0.0598
# ===> Avg. PSNR: 30.5736 dB
# ===> Running Avg. PSNR: 30.7320 dB
# ===> Epoch 123 Complete: Avg. Loss: 0.0689
# ===> Epoch 124 Complete: Avg. Loss: 0.0670
# ===> Avg. PSNR: 33.0262 dB
# ===> Running Avg. PSNR: 30.7690 dB
# ===> Epoch 125 Complete: Avg. Loss: 0.0756
# ===> Epoch 126 Complete: Avg. Loss: 0.0808
# ===> Avg. PSNR: 30.4906 dB
# ===> Running Avg. PSNR: 30.7645 dB
# ===> Epoch 127 Complete: Avg. Loss: 0.0710
# ===> Epoch 128 Complete: Avg. Loss: 0.0712
# ===> Avg. PSNR: 33.2663 dB
# ===> Running Avg. PSNR: 30.8036 dB
# ===> Epoch 129 Complete: Avg. Loss: 0.0623
# ===> Epoch 130 Complete: Avg. Loss: 0.0707
# ===> Avg. PSNR: 32.4004 dB
# ===> Running Avg. PSNR: 30.8282 dB
# ===> Epoch 131 Complete: Avg. Loss: 0.0646
# ===> Epoch 132 Complete: Avg. Loss: 0.0667
# ===> Avg. PSNR: 32.0778 dB
# ===> Running Avg. PSNR: 30.8471 dB
# ===> Epoch 133 Complete: Avg. Loss: 0.0721
# ===> Epoch 134 Complete: Avg. Loss: 0.0609
# ===> Avg. PSNR: 31.7150 dB
# ===> Running Avg. PSNR: 30.8601 dB
# ===> Epoch 135 Complete: Avg. Loss: 0.0704
# ===> Epoch 136 Complete: Avg. Loss: 0.0676
# ===> Avg. PSNR: 31.7262 dB
# ===> Running Avg. PSNR: 30.8728 dB
# ===> Epoch 137 Complete: Avg. Loss: 0.0601
# ===> Epoch 138 Complete: Avg. Loss: 0.0671
# ===> Avg. PSNR: 33.0630 dB
# ===> Running Avg. PSNR: 30.9046 dB
# ===> Epoch 139 Complete: Avg. Loss: 0.0587
# ===> Epoch 140 Complete: Avg. Loss: 0.0680
# ===> Avg. PSNR: 33.2024 dB
# ===> Running Avg. PSNR: 30.9374 dB
# ===> Epoch 141 Complete: Avg. Loss: 0.0657
# ===> Epoch 142 Complete: Avg. Loss: 0.0690
# ===> Avg. PSNR: 32.4127 dB
# ===> Running Avg. PSNR: 30.9582 dB
# ===> Epoch 143 Complete: Avg. Loss: 0.0664
# ===> Epoch 144 Complete: Avg. Loss: 0.0649
# ===> Avg. PSNR: 33.4877 dB
# ===> Running Avg. PSNR: 30.9933 dB
# ===> Epoch 145 Complete: Avg. Loss: 0.0669
# ===> Epoch 146 Complete: Avg. Loss: 0.0634
# ===> Avg. PSNR: 32.7673 dB
# ===> Running Avg. PSNR: 31.0176 dB
# ===> Epoch 147 Complete: Avg. Loss: 0.0600
# ===> Epoch 148 Complete: Avg. Loss: 0.0616
# ===> Avg. PSNR: 32.6693 dB
# ===> Running Avg. PSNR: 31.0399 dB
# ===> Epoch 149 Complete: Avg. Loss: 0.0666
# ===> Epoch 150 Complete: Avg. Loss: 0.0604
# ===> Avg. PSNR: 33.3202 dB
# ===> Running Avg. PSNR: 31.0703 dB
# ===> Epoch 151 Complete: Avg. Loss: 0.0625
# ===> Epoch 152 Complete: Avg. Loss: 0.0599
# ===> Avg. PSNR: 33.2755 dB
# ===> Running Avg. PSNR: 31.0993 dB
# ===> Epoch 153 Complete: Avg. Loss: 0.0568
# ===> Epoch 154 Complete: Avg. Loss: 0.0602
# ===> Avg. PSNR: 31.7129 dB
# ===> Running Avg. PSNR: 31.1073 dB
# ===> Epoch 155 Complete: Avg. Loss: 0.0659
# ===> Epoch 156 Complete: Avg. Loss: 0.1123
# ===> Avg. PSNR: 31.6142 dB
# ===> Running Avg. PSNR: 31.1138 dB
# ===> Epoch 157 Complete: Avg. Loss: 0.0681
# ===> Epoch 158 Complete: Avg. Loss: 0.0618
# ===> Avg. PSNR: 32.8769 dB
# ===> Running Avg. PSNR: 31.1361 dB
# ===> Epoch 159 Complete: Avg. Loss: 0.0584
# ===> Epoch 160 Complete: Avg. Loss: 0.0595
# ===> Avg. PSNR: 33.2564 dB
# ===> Running Avg. PSNR: 31.1626 dB
# ===> Epoch 161 Complete: Avg. Loss: 0.0582
# ===> Epoch 162 Complete: Avg. Loss: 0.0596
# ===> Avg. PSNR: 32.6328 dB
# ===> Running Avg. PSNR: 31.1808 dB
# ===> Epoch 163 Complete: Avg. Loss: 0.0633
# ===> Epoch 164 Complete: Avg. Loss: 0.0629
# ===> Avg. PSNR: 33.4191 dB
# ===> Running Avg. PSNR: 31.2081 dB
# ===> Epoch 165 Complete: Avg. Loss: 0.0611
# ===> Epoch 166 Complete: Avg. Loss: 0.0574
# ===> Avg. PSNR: 30.8151 dB
# ===> Running Avg. PSNR: 31.2033 dB
# ===> Epoch 167 Complete: Avg. Loss: 0.0636
# ===> Epoch 168 Complete: Avg. Loss: 0.0644
# ===> Avg. PSNR: 31.0557 dB
# ===> Running Avg. PSNR: 31.2016 dB
# ===> Epoch 169 Complete: Avg. Loss: 0.0621
# ===> Epoch 170 Complete: Avg. Loss: 0.0611
# ===> Avg. PSNR: 32.0118 dB
# ===> Running Avg. PSNR: 31.2111 dB
# ===> Epoch 171 Complete: Avg. Loss: 0.0592
# ===> Epoch 172 Complete: Avg. Loss: 0.0551
# ===> Avg. PSNR: 32.7049 dB
# ===> Running Avg. PSNR: 31.2285 dB
# ===> Epoch 173 Complete: Avg. Loss: 0.0581
# ===> Epoch 174 Complete: Avg. Loss: 0.0571
# ===> Avg. PSNR: 32.7166 dB
# ===> Running Avg. PSNR: 31.2456 dB
# ===> Epoch 175 Complete: Avg. Loss: 0.0609
# ===> Epoch 176 Complete: Avg. Loss: 0.0616
# ===> Avg. PSNR: 33.3695 dB
# ===> Running Avg. PSNR: 31.2697 dB
# ===> Epoch 177 Complete: Avg. Loss: 0.0602
# ===> Epoch 178 Complete: Avg. Loss: 0.0588
# ===> Avg. PSNR: 31.6712 dB
# ===> Running Avg. PSNR: 31.2742 dB
# ===> Epoch 179 Complete: Avg. Loss: 0.0508
# ===> Epoch 180 Complete: Avg. Loss: 0.0551
# ===> Avg. PSNR: 33.6710 dB
# ===> Running Avg. PSNR: 31.3009 dB
# ===> Epoch 181 Complete: Avg. Loss: 0.0560
# ===> Epoch 182 Complete: Avg. Loss: 0.0630
# ===> Avg. PSNR: 32.3637 dB
# ===> Running Avg. PSNR: 31.3125 dB
# ===> Epoch 183 Complete: Avg. Loss: 0.0546
# ===> Epoch 184 Complete: Avg. Loss: 0.0544
# ===> Avg. PSNR: 31.2872 dB
# ===> Running Avg. PSNR: 31.3123 dB
# ===> Epoch 185 Complete: Avg. Loss: 0.0550
# ===> Epoch 186 Complete: Avg. Loss: 0.0620
# ===> Avg. PSNR: 32.8232 dB
# ===> Running Avg. PSNR: 31.3285 dB
# ===> Epoch 187 Complete: Avg. Loss: 0.0613
# ===> Epoch 188 Complete: Avg. Loss: 0.0577
# ===> Avg. PSNR: 31.7745 dB
# ===> Running Avg. PSNR: 31.3333 dB
# ===> Epoch 189 Complete: Avg. Loss: 0.0589
# ===> Epoch 190 Complete: Avg. Loss: 0.0575
# ===> Avg. PSNR: 33.2573 dB
# ===> Running Avg. PSNR: 31.3535 dB
# ===> Epoch 191 Complete: Avg. Loss: 0.0514
# ===> Epoch 192 Complete: Avg. Loss: 0.0513
# ===> Avg. PSNR: 33.5307 dB
# ===> Running Avg. PSNR: 31.3762 dB
# ===> Epoch 193 Complete: Avg. Loss: 0.0558
# ===> Epoch 194 Complete: Avg. Loss: 0.0657
# ===> Avg. PSNR: 32.9773 dB
# ===> Running Avg. PSNR: 31.3927 dB
# ===> Epoch 195 Complete: Avg. Loss: 0.0535
# ===> Epoch 196 Complete: Avg. Loss: 0.0581
# ===> Avg. PSNR: 32.6849 dB
# ===> Running Avg. PSNR: 31.4059 dB
# ===> Epoch 197 Complete: Avg. Loss: 0.0499
# ===> Epoch 198 Complete: Avg. Loss: 0.0587
# ===> Avg. PSNR: 32.4389 dB
# ===> Running Avg. PSNR: 31.4163 dB
# ===> Epoch 199 Complete: Avg. Loss: 0.0587
# ===> Epoch 200 Complete: Avg. Loss: 0.0582
# ===> Avg. PSNR: 32.2125 dB
# ===> Running Avg. PSNR: 31.4243 dB
# it took 1078.7816214561462 seconds

# %%
def save_checkpoint(state):
    date = arrow.now('US/Eastern').format('YY-MM-DD_HHmm')
    model_out_path = "model_epoch_{}_{}.pth".format(epoch,date)
    torch.save(state, model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))

save_checkpoint({
    'epoch': epoch + 1,
    'arch': model,
    'state_dict': model.state_dict(),
    'optimizer' : optimizer.state_dict(),
      })
# Out:
# Checkpoint saved to model_epoch_200_21-07-06_1549.pth

# %%
torch.save(model,'CNN_noise.pth')

# %%
from piq import ssim, psnr
import glob
import xarray as xr
import scipy

# %%
class inference:
    def __init__(self,theta,range_x1,range_x2,range_y1,range_y2,percent_noise):
        
        
        self.llc = xr.open_dataset(theta)
        self.sst = np.asarray(self.llc['Theta'])
        self.sst_pil = Image.fromarray(self.sst)
        self.sst_pil_large = self.sst_pil.resize((self.sst_pil.width*2,self.sst_pil.height*2))
        self.sst_1km = np.asarray(self.sst_pil_large)
    
        self.foot = np.asarray(scipy.io.loadmat('mean_along_scan_footprint.mat')['footAverage'])
        self.foot_pil = Image.fromarray(self.foot)
        self.foot_pil_large = self.foot_pil.resize((self.foot_pil.width*4,self.foot_pil.height*4))
        self.foot_large = np.asarray(self.foot_pil_large)/16

        self.sst = torch.from_numpy(self.sst_1km.copy()).unsqueeze(0).unsqueeze(0).float(); #print(self.sst.shape)
        self.foot = torch.from_numpy(self.foot_large.copy()).unsqueeze(0).unsqueeze(0).float(); #print(self.foot.shape)

        self.modisfoot = torch.from_numpy(np.ones((10,10))/100).unsqueeze(0).unsqueeze(0).float(); #print(self.modisfoot.shape)

        self.amsre = torch.nn.functional.conv2d(self.sst,self.foot,stride=10); #print(self.amsre.shape)
        self.modis = torch.nn.functional.conv2d(self.sst,self.modisfoot,stride=10);

        self.modis = self.modis[:,:,:-12,:-9];# amsre footprint is larger. i don't like using padding. therefore modis has more convolved data so this cuts the excess
    
        self.target = self.modis-self.amsre
                
        self.amsre_patch = self.amsre[0,:,range_x1:range_x2,range_y1:range_y2].unsqueeze(0);print(self.amsre_patch.shape)
        self.modis_patch = self.modis[0,:,range_x1:range_x2,range_y1:range_y2].unsqueeze(0)   
        self.noise = torch.randn(self.amsre_patch.shape)
        self.percent_noise = percent_noise
        self.xnoise = self.noise * self.percent_noise + self.amsre_patch

        
        



# infer_choice = choice(glob.glob('../AQQQA/LLC_ai_sst/ThetaUVSalt/*.nc'))

# print(infer_choice)

infer_choice = 'AQQQA/LLC_ai_sst/ThetaUVSalt/LLC4320_2012-02-24T12_00_00.nc'
infer = inference((infer_choice),1850,1950,3200,3250,0.5)


class dp_patches(Dataset):
    def __init__(self,inp,target):
        self.x = inp
        self.y = target
        self.z = self.y - self.x
    def __getitem__(self,idx):
        x = self.x[idx].to('cuda')
        return x
    def __len__(self):
        return self.x.shape[0]
    
ds = dp_patches(infer.xnoise, infer.modis_patch)
dl = DataLoader(ds,shuffle=False)

with torch.no_grad():
    model.eval()
    for i in dl:
        prediction = model(i)
# Out:
# torch.Size([1, 1, 100, 50])

# %%
from pyresample import load_area, SwathDefinition
from pyresample.kd_tree import resample_nearest

# %%
am = xr.open_dataset('real_data/20111004060552-REMSS-L2P_GHRSST-SSTsubskin-AMSRE-l2b_v07a_r50096.dat-v02.0-fv01.0.nc')
x = torch.from_numpy(np.array(am['sea_surface_temperature'])).unsqueeze(0).unsqueeze(0)

# %%
area_def = load_area('pyresample/areas.yaml','pc_world')

# %%
amlon = np.array(am['lon'])
amlat = np.array(am['lat'])
am = np.array(x)

# %%
swath_def = SwathDefinition(amlon,amlat)
result = resample_nearest(swath_def,am,area_def,
                          radius_of_influence=10000,fill_value=None)

# %%
plt.imshow(result[9500:9900,13850:14500],cmap='jet')
plt.colorbar()

# %%
yo = torch.from_numpy(np.array(result[9500:9900,13850:14500]-273.15)).unsqueeze(0).unsqueeze(0)
type(yo)
# Out:
# torch.Tensor

# %%
ds = dp_patches(yo,yo)

# %%
dl = DataLoader(ds,shuffle=False)
with torch.no_grad():
    model.eval()
    for i in dl:
        prediction = model(i)

# %%
plt.imshow(prediction.cpu()[0,0,:,:] + yo[0,0,:,:],cmap='jet')
plt.colorbar()

# %%
plt.imshow(prediction.cpu()[0,0,:,:] + ds.x.cpu()[0,0,:,:],cmap='jet')
plt.figure()
plt.imshow(ds.x.cpu()[0,0,:,:],cmap='jet')
plt.figure()
plt.imshow(ds.y.cpu()[0,0,:,:],cmap='jet')

# %%
pwd
# Out:
# '/home/albertl_uri_edu'

# %%
amsr2 = torch.load('dlfromopendap/amsre2.pt')

# %%
amsr2.shape
# Out:
# (12960, 17280)

# %%
plt.imshow(amsr2[3600:4050,5200:5850],cmap='jet')
plt.colorbar()

# %%
amsr2arr = amsr2[3600:4000,5200:5850] - 273.15
amsr2arr = np.where(np.isfinite(amsr2arr) == True, amsr2arr,np.nan)

# %%
amsr2arr.shape
# Out:
# (400, 650)

# %%
type(amsr2arr)
# Out:
# numpy.ndarray

# %%
plt.imshow(amsr2arr,cmap='jet')

# %%
yoo = torch.from_numpy(amsr2arr).unsqueeze(0).unsqueeze(0)
ds = dp_patches(yoo,yoo)
dl = DataLoader(ds,shuffle=False)
with torch.no_grad():
    model.eval()
    for i in dl:
        prediction = model(i)
plt.imshow(prediction.cpu()[0,0,:,:] + yoo[0,0,:,:],cmap='jet')
plt.colorbar()

# %%
def zero_to_one(inp):
    xmin = torch.min(inp)
    inp -= xmin
    xmax = torch.max(inp)
    inp /= xmax
    return inp

# %%
amsreCNN_noise = np.asarray(infer.xnoise[0,0,:-4,:-4])
print(amsreCNN_noise.shape)

modisCNN_noise = np.asarray(infer.modis_patch[0,0,:-4,:-4])
print(modisCNN_noise.shape)

predictedCNN_noise = np.asarray(prediction.cpu()[0,0,:-4,:-4]+infer.xnoise.cpu()[0,0,:-4,:-4])
print(predictedCNN_noise.shape)

amsreGRAD = np.asarray(apmag[0,0,:,:]);
modisGRAD = np.asarray(mpmag[0,0,:,:])
predictedGRAD = np.asarray(cpmag[0,0,:,:])

np.savez('CNNimages_noise_withgrads.npz',x=amsreCNN_noise,y=modisCNN_noise,z=predictedCNN_noise,a=amsreGRAD,b=modisGRAD,c=predictedGRAD)
# Out:
# (220, 220)
# (220, 220)
# (220, 220)

# %%
plt.figure()

plt.figure()
plt.imshow(infer.xnoise.cpu()[0,0,:-4,:-4],cmap='jet')
vmin, vmax = plt.gci().get_clim()
plt.colorbar()

plt.figure()
plt.imshow(infer.modis_patch.cpu()[0,0,:-4,:-4],cmap='jet',vmin=vmin,vmax=vmax)
plt.colorbar()


plt.figure()
plt.imshow(prediction.cpu()[0,0,:-4,:-4]+infer.xnoise.cpu()[0,0,:-4,:-4],cmap='jet',vmin=vmin,vmax=vmax)
plt.colorbar()


plt.figure()
plt.imshow(infer.modis_patch[0,0,:-4,:-4]-infer.xnoise[0,0,:-4,:-4],cmap='jet',vmin=-1,vmax=3)
plt.colorbar()

plt.figure()
plt.imshow(infer.modis_patch[0,0,:-4,:-4]-infer.modis_patch[0,0,:-4,:-4],cmap='jet',vmin=-1,vmax=3)
plt.colorbar()

plt.figure()
plt.imshow(infer.modis_patch[0,0,:-4,:-4]-(prediction.cpu()[0,0,:-4,:-4]+infer.xnoise.cpu()[0,0,:-4,:-4]),cmap='jet',vmin=-1,vmax=3)
plt.colorbar()


g1 = torch.from_numpy(np.array([[1,1],[-1,-1]])).unsqueeze(0).unsqueeze(0).float()
g2 = torch.from_numpy(np.array([[1,-1],[1,-1]])).unsqueeze(0).unsqueeze(0).float()

modis_patch_g1 = torch.nn.functional.conv2d(infer.modis_patch[:,:,:-4,:-4],g1)
modis_patch_g2 = torch.nn.functional.conv2d(infer.modis_patch[:,:,:-4,:-4],g2)

mpmag = torch.sqrt(torch.pow(modis_patch_g1,2)+torch.pow(modis_patch_g2,2))

amsre_patch_g1 = torch.nn.functional.conv2d(infer.xnoise[:,:,:-4,:-4],g1)
amsre_patch_g2 = torch.nn.functional.conv2d(infer.xnoise[:,:,:-4,:-4],g2)

apmag = torch.sqrt(torch.pow(amsre_patch_g1,2)+torch.pow(amsre_patch_g2,2))

correct_g1 = torch.nn.functional.conv2d(prediction.cpu()[:,:,:-4,:-4]+infer.xnoise.cpu()[:,:,:-4,:-4],g1)
correct_g2 = torch.nn.functional.conv2d(prediction.cpu()[:,:,:-4,:-4]+infer.xnoise.cpu()[:,:,:-4,:-4],g2)

cpmag = torch.sqrt(torch.pow(correct_g1,2)+torch.pow(correct_g2,2))


plt.figure()
plt.imshow(apmag[0,0,:,:],cmap='jet',vmin=0,vmax=8)
plt.colorbar()

plt.figure()
plt.imshow(mpmag[0,0,:,:],cmap='jet',vmin=0,vmax=8)
plt.colorbar()

plt.figure()
plt.imshow(cpmag[0,0,:,:],cmap='jet',vmin=0,vmax=8)
plt.colorbar()

# %%
g1 = torch.from_numpy(np.array([[1,1],[-1,-1]])).unsqueeze(0).unsqueeze(0).float()
g2 = torch.from_numpy(np.array([[1,-1],[1,-1]])).unsqueeze(0).unsqueeze(0).float()

with torch.no_grad():
    for zz,xx,yy in valid_dataloader:
        target = yy-xx
        predicted = model(zz)
        

        modis_patch_g1 = torch.nn.functional.conv2d(yy.cpu(),g1)
        modis_patch_g2 = torch.nn.functional.conv2d(yy.cpu(),g2)

        mpmag = torch.sqrt(torch.pow(modis_patch_g1,2)+torch.pow(modis_patch_g2,2))

        amsre_patch_g1 = torch.nn.functional.conv2d(zz.cpu(),g1)
        amsre_patch_g2 = torch.nn.functional.conv2d(zz.cpu(),g2)

        apmag = torch.sqrt(torch.pow(amsre_patch_g1,2)+torch.pow(amsre_patch_g2,2))

        correct_g1 = torch.nn.functional.conv2d(predicted.cpu()[0,0,:,:]+zz.cpu(),g1)
        correct_g2 = torch.nn.functional.conv2d(predicted.cpu()[0,0,:,:]+zz.cpu(),g2)

        cpmag = torch.sqrt(torch.pow(correct_g1,2)+torch.pow(correct_g2,2))
        

        plt.figure()
        plt.imshow(zz.cpu()[0,0,:,:],cmap='jet')
        plt.title('AMSR-E (°C)')
        vmin, vmax = plt.gci().get_clim()
        plt.colorbar()
        plt.axis('off')
        plt.savefig('NASA_report/CNN_noisy_amsre.png')
        
        plt.figure()
        plt.imshow(yy.cpu()[0,0,:,:],cmap='jet',vmin=vmin,vmax=vmax)
        plt.title('Target (°C)')
        plt.colorbar()
        plt.axis('off')
        plt.savefig('NASA_report/CNN_noisy_target.png')

        plt.figure()
        plt.imshow(predicted.cpu()[0,0,:,:]+zz.cpu()[0,0,:,:],cmap='jet',vmin=vmin,vmax=vmax)
        plt.title('Prediction (°C)')
        plt.colorbar()
        plt.axis('off')

        plt.savefig('NASA_report/CNN_noisy_predicted.png')
        
        plt.figure()
        plt.imshow(yy.cpu()[0,0,:,:] - zz.cpu()[0,0,:,:],cmap='jet')
        plt.title('Target - AMSR-E (°C)')
        vmin, vmax = plt.gci().get_clim()
        plt.colorbar()
        plt.axis('off')
        plt.savefig('NASA_report/CNN_noisy_target-amsre.png')
        
        plt.figure()
        plt.imshow(yy.cpu()[0,0,:,:] - yy.cpu()[0,0,:,:],cmap='jet',vmin=vmin,vmax=vmax)
        plt.title('Target - Target (°C)')
        plt.colorbar()
        plt.axis('off')
        plt.savefig('NASA_report/CNN_noisy_target-target.png')

        plt.figure()
        plt.imshow(yy.cpu()[0,0,:,:] - (predicted.cpu()[0,0,:,:]+zz.cpu()[0,0,:,:]),cmap='jet',vmin=vmin,vmax=vmax)
        plt.title('Target - Prediction (°C)')
        plt.colorbar()
        plt.axis('off')
        plt.savefig('NASA_report/CNN_noisy_target-prediction.png')
        
        
        plt.figure()
        plt.title('Target, Gradient')
        plt.imshow(mpmag[0,0,:,:],cmap='jet')
        vmin, vmax = plt.gci().get_clim()
        plt.colorbar()
        plt.axis('off')
        plt.savefig('NASA_report/CNN_noisy_target_gradient.png')
        
        plt.figure()
        plt.title('AMSR-E, Gradient')
        plt.imshow(apmag[0,0,:,:],cmap='jet',vmin=vmin,vmax=vmax)
        plt.colorbar()
        plt.axis('off')
        plt.savefig('NASA_report/CNN_noisy_amsre_gradient.png')
        
        plt.figure()
        plt.title('Predicted, Gradient')
        plt.imshow(cpmag[0,0,:,:],cmap='jet',vmin=vmin,vmax=vmax)
        plt.colorbar()
        plt.axis('off')
        plt.savefig('NASA_report/CNN_noisy_predicted_gradient.png')
        
        break

# %%
plt.imshow(predicted.cpu()[0,0,:,:]+zz.cpu()[0,0,:,:],cmap='jet')
plt.colorbar()

# %%
print(torch.nn.functional.mse_loss(b,a))
print(torch.nn.functional.mse_loss(b,c))
# Out:
# tensor(0.0028)
# tensor(0.0005)

# %%
a = zz.cpu()[0,0,:,:]
b = yy.cpu()[0,0,:,:]
c = predicted.cpu()[0,0,:,:]+zz.cpu()[0,0,:,:]

print(mean_squared_error(b,a))
print(mean_squared_error(b,c))

amin = torch.min(a)
a -= amin

amax = torch.max(a)
a /= amax
plt.figure()
plt.imshow(a)
plt.colorbar()

bmin = torch.min(b)
b -= bmin

bmax = torch.max(b)
b /= bmax

plt.figure()
plt.imshow(b)
plt.colorbar()

cmin = torch.min(c)
c -= cmin

cmax = torch.max(c)
c /= cmax

plt.figure()
plt.imshow(c)
plt.colorbar()

print(mean_squared_error(a,b))
print(mean_squared_error(a,c))

print(10*np.log10(np.power(np.max(a.numpy().reshape(-1)),2) / mean_squared_error(a,b)))
print(10*np.log10(np.power(np.max(a.numpy().reshape(-1)),2) / mean_squared_error(a,c)))
# Out:
# 0.24956742
# 0.066702455
# 0.002754903
# 0.0030356324
# 25.598936986252898
# 25.177508165217528
